# %%
import pickle 
file_pi2 = open('savedStrategies/sf_0.obj', 'rb') 
object_pi2 = pickle.load(file_pi2)

# %%
object_pi2.print_best_iteration_summaries()
# Out:
# ____________________________ Summary _________________________________
#
# Item                           value  Item                    Value
# ------------------------  ----------  -----------------  ----------
# Annualized Return           0.136416  Cumulative Return    0.100756
# Net Profit                271.92
# Gross Profit              328.7       Gross Loss         -56.78
# Reward Risk Ratio          28.2664    Equity Smoothness   20.2521
# Return Over Max Drawdown    1.53532
#
# ____________________________ Hypothesis Test _________________________________
#
# Item                        value  Item                            Value
# ---------------------  ----------  ---------------------------  --------
# Daily Sharpe Ratio       0.050509  Sharpe Ratio                 0.801805
# Number of Days         274         Sharpe Ratio Critical Value  0.658556
# Sharpe Ratio P Value:    0.25509
# ****** Summary *******
# Annualized Return: 13.64%
# Max Drawdown: 6.6%
# ...
