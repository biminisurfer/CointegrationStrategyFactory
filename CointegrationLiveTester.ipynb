# %% [markdown]
# #####

# %%
from CointegrationLiveTester import CointegrationLiveTester

# %%
data = {
    
    'live_test_start_date': '2022-5-18',
    'filename': 'LiveTradeIndustrials',
    'max_backtests': 5,
    'max_allowable_allocation': 0.75,
    'initial_cash': 4000,
    'description': 'This is the first real live trade that we are starting on 2022-05-18'
}

lt = CointegrationLiveTester(data)

# %%
lt.run(print_backtest_summary=True)
lt.plot_combined_strategies()
lt.perform_t_test(alpha=0.05, verbose=True)
lt.perform_monte_carlo(total_trading_days=60, simulations=100, plot_results=True)
# Out:
# 1
# 4
# 2
# 0
# 5
# Run Backtest Up To Today
# Symbol: FAST, start_date: 2021-10-1, end_date: None
# Last_datetime: 2022-05-25
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Broker Model: Total purchase cost of 862.5399932861328 exceeds cash of 768.7700271606445, bugging out
# Broker Model: Total purchase cost of 1031.9100036621094 exceeds cash of 1001.3799896240234, bugging out
# ____________________________ Summary _________________________________
# Symbols: ['FAST', 'JBHT', 'SNA']
# Vectors: [  3.3920103   -3.23263318 -17.05555948]
#
# Item                           value  Item                    Value
# ------------------------  ----------  -----------------  ----------
# Annualized Return            1.21736  Cumulative Return     0.41775
# Net Profit                1948.66
# Gross Profit              2142.32     Gross Loss         -193.66
# Reward Risk Ratio           98.9804   Equity Smoothness    58.7545
# Return Over Max Drawdown    10.8387
#
# ____________________________ Hypothesis Test _________________________________
#
# Item                          value  Item                           Value
# ---------------------  ------------  ---------------------------  -------
# Daily Sharpe Ratio       0.230536    Sharpe Ratio                 3.65965
# Number of Days         160           Sharpe Ratio Critical Value  2.91608
# Sharpe Ratio P Value:    0.00177229
# ****** Summary *******
# Annualized Return: 121.74%
# Max Drawdown: 3.9%
# Total Trading Days: 0
# Start Equity: 4000
# End Equity: 5671
# Profits: 1671
# Cumulative Return: 41.78%
# Fees: 14.7
# Total Trades: 42
# Open Trades
# 3.0 shares of FAST purchased on 2022-05-04 00:00:00 at 54.76
# -3.0 shares of JBHT purchased on 2022-05-04 00:00:00 at 172.57
# -16.0 shares of SNA purchased on 2022-05-04 00:00:00 at 220.55
# Open Orders:
# No open orders
# Live Trade
# Symbol: FAST, start_date: 2022-5-18, end_date: None
# Last_datetime: 2022-05-25
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# /home/joseph/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# ____________________________ Summary _________________________________
# Symbols: ['FAST', 'JBHT', 'SNA']
# Vectors: [  3.3920103   -3.23263318 -17.05555948]
#
# Item                         value  Item                     Value
# ------------------------  --------  -----------------  -----------
# Annualized Return          0        Cumulative Return  0
# Net Profit                 0
# Gross Profit               0        Gross Loss         0
# Reward Risk Ratio         -1.85945  Equity Smoothness  9.91099e-13
# Return Over Max Drawdown   0
#
# ____________________________ Hypothesis Test _________________________________
#
# Item                     value  Item                           Value
# ---------------------  -------  ---------------------------  -------
# Daily Sharpe Ratio         0    Sharpe Ratio                       0
# Number of Days             6    Sharpe Ratio Critical Value        0
# Sharpe Ratio P Value:      0.5
# ****** Summary *******
# Annualized Return: 0.0%
# Max Drawdown: -0.0%
# Total Trading Days: 0
# Start Equity: 4000
# End Equity: 4000
# Profits: 0
# Cumulative Return: 0.0%
# Fees: 0
# Total Trades: 0
# Open Trades
# Open Orders:
# No open orders
# ************** Live Trade Orders *****************
# No live trade orders
# *************** Open Orders ******************
# Empty DataFrame
# Columns: [shares, trade_index, order_date, symbol, executed]
# Index: []
# Run Backtest Up To Today
# Symbol: EMR, start_date: 2021-10-1, end_date: None
# Last_datetime: 2022-05-25
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ____________________________ Summary _________________________________
# Symbols: ['EMR', 'SNA', 'WAB']
# Vectors: [ 7.44440776 53.05012331 18.47605279]
#
# Item                           value  Item                  Value
# ------------------------  ----------  -----------------  --------
# Annualized Return            1.09705  Cumulative Return    0.3835
# Net Profit                1825
# Gross Profit              1860.13     Gross Loss         -35.1299
# Reward Risk Ratio           82.7171   Equity Smoothness   64.6387
# Return Over Max Drawdown     8.70561
#
# ____________________________ Hypothesis Test _________________________________
#
# Item                          value  Item                           Value
# ---------------------  ------------  ---------------------------  -------
# Daily Sharpe Ratio       0.238697    Sharpe Ratio                 3.7892
# Number of Days         160           Sharpe Ratio Critical Value  3.01931
# Sharpe Ratio P Value:    0.00126676
# ****** Summary *******
# Annualized Return: 109.7%
# Max Drawdown: 4.4%
# Total Trading Days: 0
# Start Equity: 4000
# End Equity: 5534
# Profits: 1534
# Cumulative Return: 38.35%
# Fees: 15.75
# Total Trades: 45
# Open Trades
# -2.0 shares of EMR purchased on 2022-05-18 00:00:00 at 86.04
# -15.0 shares of SNA purchased on 2022-05-18 00:00:00 at 222.0
# -5.0 shares of WAB purchased on 2022-05-18 00:00:00 at 88.9
# Open Orders:
# No open orders
# Live Trade
# Symbol: EMR, start_date: 2022-5-18, end_date: None
# Last_datetime: 2022-05-25
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ____________________________ Summary _________________________________
# Symbols: ['EMR', 'SNA', 'WAB']
# Vectors: [ 7.44440776 53.05012331 18.47605279]
#
# Item                         value  Item                     Value
# ------------------------  --------  -----------------  -----------
# Annualized Return          0        Cumulative Return  0
# Net Profit                 0
# Gross Profit               0        Gross Loss         0
# Reward Risk Ratio         -1.85945  Equity Smoothness  9.91099e-13
# Return Over Max Drawdown   0
#
# ____________________________ Hypothesis Test _________________________________
#
# Item                     value  Item                           Value
# ---------------------  -------  ---------------------------  -------
# Daily Sharpe Ratio         0    Sharpe Ratio                       0
# Number of Days             6    Sharpe Ratio Critical Value        0
# Sharpe Ratio P Value:      0.5
# ****** Summary *******
# Annualized Return: 0.0%
# Max Drawdown: -0.0%
# Total Trading Days: 0
# Start Equity: 4000
# End Equity: 4000
# Profits: 0
# Cumulative Return: 0.0%
# Fees: 0
# Total Trades: 0
# Open Trades
# Open Orders:
# No open orders
# /home/joseph/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# ************** Live Trade Orders *****************
# No live trade orders
# *************** Open Orders ******************
# Empty DataFrame
# Columns: [shares, trade_index, order_date, symbol, executed]
# Index: []
# Run Backtest Up To Today
# Symbol: DAL, start_date: 2021-10-1, end_date: None
# Last_datetime: 2022-05-25
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Broker Model: Total purchase cost of 903.1300048828124 exceeds cash of 746.4799728393558, bugging out
# Broker Model: Total purchase cost of 856.3099975585938 exceeds cash of 828.230007171631, bugging out
# ____________________________ Summary _________________________________
# Symbols: ['DAL', 'SNA', 'UNP']
# Vectors: [  2.40684112 -19.38036275  -3.84270606]
#
# Item                           value  Item                    Value
# ------------------------  ----------  -----------------  ----------
# Annualized Return            1.27667  Cumulative Return     0.43425
# Net Profit                1956.7
# Gross Profit              2088.8      Gross Loss         -132.1
# Reward Risk Ratio           81.5156   Equity Smoothness    65.1025
# Return Over Max Drawdown    18.2854
#
# ____________________________ Hypothesis Test _________________________________
#
# Item                           value  Item                           Value
# ---------------------  -------------  ---------------------------  -------
# Daily Sharpe Ratio       0.26422      Sharpe Ratio                 4.19436
# Number of Days         160            Sharpe Ratio Critical Value  3.34214
# Sharpe Ratio P Value:    0.000415668
# ****** Summary *******
# Annualized Return: 127.67%
# Max Drawdown: 2.4%
# Total Trading Days: 0
# Start Equity: 4000
# End Equity: 5737
# Profits: 1737
# Cumulative Return: 43.42%
# Fees: 14.7
# Total Trades: 42
# Open Trades
# 1.0 shares of DAL purchased on 2022-05-18 00:00:00 at 40.31
# -16.0 shares of SNA purchased on 2022-05-18 00:00:00 at 222.0
# -4.0 shares of UNP purchased on 2022-05-18 00:00:00 at 232.32
# Open Orders:
# No open orders
# Live Trade
# Symbol: DAL, start_date: 2022-5-18, end_date: None
# Last_datetime: 2022-05-25
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ____________________________ Summary _________________________________
# Symbols: ['DAL', 'SNA', 'UNP']
# Vectors: [  2.40684112 -19.38036275  -3.84270606]
#
# Item                         value  Item                 Value
# ------------------------  --------  -----------------  -------
# Annualized Return         0.623737  Cumulative Return   0.008
# Net Profit                0
# Gross Profit              0         Gross Loss          0
# Reward Risk Ratio         1.15076   Equity Smoothness  13.9178
# Return Over Max Drawdown  4.57143
#
# ____________________________ Hypothesis Test _________________________________
#
# Item                      value  Item                            Value
# ---------------------  --------  ---------------------------  --------
# Daily Sharpe Ratio     0.321227  Sharpe Ratio                 5.09932
# Number of Days         6         Sharpe Ratio Critical Value  0.786843
# Sharpe Ratio P Value:  0.215687
# ****** Summary *******
# Annualized Return: 62.37%
# Max Drawdown: 0.2%
# Total Trading Days: 0
# Start Equity: 4000
# End Equity: 4032
# Profits: 32
# Cumulative Return: 0.8%
# Fees: 0
# Total Trades: 0
# Open Trades
# -1.0 shares of DAL purchased on 2022-05-23 00:00:00 at 39.38
# 12.0 shares of SNA purchased on 2022-05-23 00:00:00 at 211.97
# 3.0 shares of UNP purchased on 2022-05-23 00:00:00 at 215.49
# Open Orders:
# No open orders
# ************** Live Trade Orders *****************
# No live trade orders
# *************** Open Orders ******************
#    shares trade_index order_date symbol executed
# 0    -1.0        None 2022-05-20    DAL        1
# 1    12.0        None 2022-05-20    SNA        1
# 2     3.0        None 2022-05-20    UNP        1
# 3     1.0           0 2022-05-25    DAL        0
# 4   -12.0           1 2022-05-25    SNA        0
# 5    -3.0           2 2022-05-25    UNP        0
# Run Backtest Up To Today
# Symbol: CSX, start_date: 2021-10-1, end_date: None
# Last_datetime: 2022-05-25
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ____________________________ Summary _________________________________
# Symbols: ['CSX', 'SNA', 'WAB']
# Vectors: [ 7.15714534 28.61861944  4.47577749]
#
# Item                           value  Item                  Value
# ------------------------  ----------  -----------------  --------
# Annualized Return            1.28664  Cumulative Return    0.437
# Net Profit                2027.96
# Gross Profit              2040.56     Gross Loss         -12.6001
# Reward Risk Ratio           81.2993   Equity Smoothness   73.1435
# Return Over Max Drawdown     9.49177
#
# ____________________________ Hypothesis Test _________________________________
#
# Item                          value  Item                           Value
# ---------------------  ------------  ---------------------------  -------
# Daily Sharpe Ratio       0.238809    Sharpe Ratio                 3.79097
# Number of Days         160           Sharpe Ratio Critical Value  3.02072
# Sharpe Ratio P Value:    0.00126088
# ****** Summary *******
# Annualized Return: 128.66%
# Max Drawdown: 4.6%
# Total Trading Days: 0
# Start Equity: 4000
# End Equity: 5748
# Profits: 1748
# Cumulative Return: 43.7%
# Fees: 15.75
# Total Trades: 45
# Open Trades
# -4.0 shares of CSX purchased on 2022-05-18 00:00:00 at 33.69
# -17.0 shares of SNA purchased on 2022-05-18 00:00:00 at 222.0
# -2.0 shares of WAB purchased on 2022-05-18 00:00:00 at 88.9
# Open Orders:
# No open orders
# Live Trade
# Symbol: CSX, start_date: 2022-5-18, end_date: None
# Last_datetime: 2022-05-25
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# /home/joseph/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# ____________________________ Summary _________________________________
# Symbols: ['CSX', 'SNA', 'WAB']
# Vectors: [ 7.15714534 28.61861944  4.47577749]
#
# Item                         value  Item                     Value
# ------------------------  --------  -----------------  -----------
# Annualized Return          0        Cumulative Return  0
# Net Profit                 0
# Gross Profit               0        Gross Loss         0
# Reward Risk Ratio         -1.85945  Equity Smoothness  9.91099e-13
# Return Over Max Drawdown   0
#
# ____________________________ Hypothesis Test _________________________________
#
# Item                     value  Item                           Value
# ---------------------  -------  ---------------------------  -------
# Daily Sharpe Ratio         0    Sharpe Ratio                       0
# Number of Days             6    Sharpe Ratio Critical Value        0
# Sharpe Ratio P Value:      0.5
# ****** Summary *******
# Annualized Return: 0.0%
# Max Drawdown: -0.0%
# Total Trading Days: 0
# Start Equity: 4000
# End Equity: 4000
# Profits: 0
# Cumulative Return: 0.0%
# Fees: 0
# Total Trades: 0
# Open Trades
# Open Orders:
# No open orders
# ************** Live Trade Orders *****************
# No live trade orders
# *************** Open Orders ******************
# Empty DataFrame
# Columns: [shares, trade_index, order_date, symbol, executed]
# Index: []
# Run Backtest Up To Today
# Symbol: SNA, start_date: 2021-10-1, end_date: None
# Last_datetime: 2022-05-25
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ____________________________ Summary _________________________________
# Symbols: ['SNA', 'UPS', 'GWW']
# Vectors: [82.68036339 13.09407246 13.25671044]
#
# Item                           value  Item                   Value
# ------------------------  ----------  -----------------  ---------
# Annualized Return            1.00401  Cumulative Return    0.35625
# Net Profit                1761.1
# Gross Profit              1781.65     Gross Loss         -20.55
# Reward Risk Ratio           79.0232   Equity Smoothness   58.6363
# Return Over Max Drawdown    12.4987
#
# ____________________________ Hypothesis Test _________________________________
#
# Item                           value  Item                           Value
# ---------------------  -------------  ---------------------------  -------
# Daily Sharpe Ratio       0.278034     Sharpe Ratio                 4.41365
# Number of Days         160            Sharpe Ratio Critical Value  3.51688
# Sharpe Ratio P Value:    0.000218323
# ****** Summary *******
# Annualized Return: 100.4%
# Max Drawdown: 2.9%
# Total Trading Days: 0
# Start Equity: 4000
# End Equity: 5425
# Profits: 1425
# Cumulative Return: 35.62%
# Fees: 16.8
# Total Trades: 48
# Open Trades
# -12.0 shares of SNA purchased on 2022-05-18 00:00:00 at 222.0
# -1.0 shares of UPS purchased on 2022-05-18 00:00:00 at 179.48
# -1.0 shares of GWW purchased on 2022-05-18 00:00:00 at 476.42
# Open Orders:
# No open orders
# Live Trade
# Symbol: SNA, start_date: 2022-5-18, end_date: None
# Last_datetime: 2022-05-25
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ____________________________ Summary _________________________________
# Symbols: ['SNA', 'UPS', 'GWW']
# Vectors: [82.68036339 13.09407246 13.25671044]
#
# Item                         value  Item                     Value
# ------------------------  --------  -----------------  -----------
# Annualized Return          0        Cumulative Return  0
# Net Profit                 0
# Gross Profit               0        Gross Loss         0
# Reward Risk Ratio         -1.85945  Equity Smoothness  9.91099e-13
# Return Over Max Drawdown   0
#
# ____________________________ Hypothesis Test _________________________________
#
# Item                     value  Item                           Value
# ---------------------  -------  ---------------------------  -------
# Daily Sharpe Ratio         0    Sharpe Ratio                       0
# Number of Days             6    Sharpe Ratio Critical Value        0
# Sharpe Ratio P Value:      0.5
# ****** Summary *******
# Annualized Return: 0.0%
# Max Drawdown: -0.0%
# Total Trading Days: 0
# Start Equity: 4000
# End Equity: 4000
# Profits: 0
# Cumulative Return: 0.0%
# Fees: 0
# Total Trades: 0
# Open Trades
# Open Orders:
# No open orders
# /home/joseph/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# ************** Live Trade Orders *****************
# No live trade orders
# *************** Open Orders ******************
# Empty DataFrame
# Columns: [shares, trade_index, order_date, symbol, executed]
# Index: []
# ****************************** Completed Running Backtests *******************************
#
#
#
#
# ************************************** Live Closed Trades ****************************************************
# Empty DataFrame
# Columns: []
# Index: []
# ************************************** Live Open Trades ****************************************************
#   close_date close_price  close_trade_fee  closed_profit  fees  is_open  \
# 0       None        None              0.0            0.0   1.0      1.0
# 1       None        None              0.0            0.0   1.0      1.0
# 2       None        None              0.0            0.0   1.0      1.0
#
#    open_date  open_price  open_profit  open_trade_fee order_date  quantity  \
# 0 2022-05-23   39.380001          0.0            0.35 2022-05-20      -1.0
# 1 2022-05-23  211.970001          0.0            0.35 2022-05-20      12.0
# 2 2022-05-23  215.490005          0.0            0.35 2022-05-20       3.0
#
#   symbol
# 0    DAL
# 1    SNA
# 2    UNP
# ************************************** Live Open Orders ****************************************************
#   symbol  quantity
# 0    DAL       1.0
# 1    SNA     -12.0
# 2    UNP      -3.0
# ************************************** Target Positions ****************************************************
#   symbol  target_quantity
# 0    DAL              0.0
# 1    SNA              0.0
# 2    UNP              0.0
# ************** Combined Strategies **************
# stat=0.556, p=0.579
# Probably the same distribution
#
# ***************************** Running Monte Carlo *********************************
# Total Trading Days: 60
# Simulations: 100

# %%
lt.is_data
# Out:
#             bt_0_equity  bt_1_equity  bt_2_equity  bt_3_equity  bt_4_equity  \
# Date
# 2021-10-01         4000         4000         4000         4000         4000
# 2021-10-04         4046         4044         4055         4055         4032
# 2021-10-05         4087         4072         4093         4088         4058
# 2021-10-06         4095         4074         4106         4095         4069
# 2021-10-07         4098         4082         4105         4098         4078
# ...                 ...          ...          ...          ...          ...
# 2022-05-13         5604         5451         5577         5629         5334
# 2022-05-16         5608         5429         5577         5629         5334
# 2022-05-17         5488         5429         5577         5629         5334
# 2022-05-18         5642         5514         5682         5720         5406
# 2022-05-19         5671         5534         5737         5748         5425
#
#             total
# Date
# 2021-10-01  20000
# 2021-10-04  20232
# 2021-10-05  20398
# 2021-10-06  20439
# 2021-10-07  20461
# ...           ...
# 2022-05-13  27595
# 2022-05-16  27577
# 2022-05-17  27457
# 2022-05-18  27964
# 2022-05-19  28115
#
# [160 rows x 6 columns]
