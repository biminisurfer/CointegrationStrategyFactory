# %%
from CointegrationLiveTester import CointegrationLiveTester

# %%
data = {
    
    'live_test_start_date': '2022-5-12',
    'filename': 'FirstGoAtIt',
    'max_backtests': 5
    
}

lt = CointegrationLiveTester(data)
lt.run() # Here we can run a live test each day of the strategy
lt.plot_combined_strategies()
# Out:
# 4
# 2
# 6
# 0
# 5
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ODFL
# SNA
# TT
# Max ALlowable DD: -0.023340157940918354
# Max Allowable DD in run_backtest_2: None
# ____________________________ Summary _________________________________
# Symbols: ['ODFL', 'SNA', 'TT']
# Vectors: [ 4.75963279 35.98647993 -1.52690398]
#
# Item                            value  Item                     Value
# ------------------------  -----------  -----------------  -----------
# Annualized Return            0.911325  Cumulative Return     0.321333
# Net Profit                1243.15
# Gross Profit              1357.96      Gross Loss         -114.81
# Reward Risk Ratio           96.4446    Equity Smoothness    36.2345
# Return Over Max Drawdown     7.82564
#
# ____________________________ Hypothesis Test _________________________________
#
# Item                          value  Item                           Value
# ---------------------  ------------  ---------------------------  -------
# Daily Sharpe Ratio       0.214251    Sharpe Ratio                 3.40113
# Number of Days         157           Sharpe Ratio Critical Value  2.68456
# Sharpe Ratio P Value:    0.00363129
# ****** Summary *******
# Annualized Return: 91.13%
# Max Drawdown: 4.1%
# Total Trading Days: 0
# Start Equity: 3000
# End Equity: 3964
# Profits: 964
# Cumulative Return: 32.13%
# Fees: 14.7
# Total Trades: 42
# Open Trades
# -1.0 shares of ODFL purchased on 2022-04-20 00:00:00 at 276.12
# -10.0 shares of SNA purchased on 2022-04-20 00:00:00 at 228.45
# 1.0 shares of TT purchased on 2022-04-20 00:00:00 at 151.23
# Open Orders:
# No open orders
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ODFL
# SNA
# TT
# Max ALlowable DD: -0.023340157940918354
# Max Allowable DD in run_backtest_2: -0.023340157940918354
# ____________________________ Summary _________________________________
# Symbols: ['ODFL', 'SNA', 'TT']
# Vectors: [ 4.75963279 35.98647993 -1.52690398]
#
# Item                          value  Item                     Value
# ------------------------  ---------  -----------------  -----------
# Annualized Return          0         Cumulative Return  0
# Net Profit                 0
# Gross Profit               0         Gross Loss         0
# Reward Risk Ratio         -0.235702  Equity Smoothness  1.36424e-12
# Return Over Max Drawdown   0
#
# ____________________________ Hypothesis Test _________________________________
#
# Item                     value  Item                           Value
# ---------------------  -------  ---------------------------  -------
# Daily Sharpe Ratio         0    Sharpe Ratio                       0
# Number of Days             3    Sharpe Ratio Critical Value        0
# Sharpe Ratio P Value:      0.5
# ****** Summary *******
# Annualized Return: 0.0%
# Max Drawdown: -0.0%
# Total Trading Days: 0
# Start Equity: 3000
# End Equity: 3000
# Profits: 0
# Cumulative Return: 0.0%
# Fees: 0
# Total Trades: 0
# Open Trades
# Open Orders:
# No open orders
# /home/joseph/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# ************** Live Trade Orders *****************
# No live trade orders
# *************** Open Trades ******************
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CAT
# SNA
# UNP
# Max ALlowable DD: -0.025491329479768832
# Max Allowable DD in run_backtest_2: None
# ____________________________ Summary _________________________________
# Symbols: ['CAT', 'SNA', 'UNP']
# Vectors: [  3.33575117 -32.93259832  -6.17050477]
#
# Item                            value  Item                    Value
# ------------------------  -----------  -----------------  ----------
# Annualized Return            0.994156  Cumulative Return    0.345667
# Net Profit                1459.58
# Gross Profit              1542.8       Gross Loss         -83.22
# Reward Risk Ratio           80.5757    Equity Smoothness   41.2641
# Return Over Max Drawdown     8.64383
#
# ____________________________ Hypothesis Test _________________________________
#
# Item                          value  Item                           Value
# ---------------------  ------------  ---------------------------  -------
# Daily Sharpe Ratio       0.214048    Sharpe Ratio                 3.39791
# Number of Days         157           Sharpe Ratio Critical Value  2.68202
# Sharpe Ratio P Value:    0.00365899
# ****** Summary *******
# Annualized Return: 99.42%
# Max Drawdown: 4.0%
# Total Trading Days: 0
# Start Equity: 3000
# End Equity: 4037
# Profits: 1037
# Cumulative Return: 34.57%
# Fees: 12.6
# Total Trades: 48
# Open Trades
# Open Orders:
# No open orders
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# CAT
# SNA
# UNP
# Max ALlowable DD: -0.025491329479768832
# Max Allowable DD in run_backtest_2: -0.025491329479768832
# ____________________________ Summary _________________________________
# Symbols: ['CAT', 'SNA', 'UNP']
# Vectors: [  3.33575117 -32.93259832  -6.17050477]
#
# Item                          value  Item                     Value
# ------------------------  ---------  -----------------  -----------
# Annualized Return          0         Cumulative Return  0
# Net Profit                 0
# Gross Profit               0         Gross Loss         0
# Reward Risk Ratio         -0.235702  Equity Smoothness  1.36424e-12
# Return Over Max Drawdown   0
#
# ____________________________ Hypothesis Test _________________________________
#
# Item                     value  Item                           Value
# ---------------------  -------  ---------------------------  -------
# Daily Sharpe Ratio         0    Sharpe Ratio                       0
# Number of Days             3    Sharpe Ratio Critical Value        0
# Sharpe Ratio P Value:      0.5
# ****** Summary *******
# Annualized Return: 0.0%
# Max Drawdown: -0.0%
# Total Trading Days: 0
# Start Equity: 3000
# End Equity: 3000
# Profits: 0
# Cumulative Return: 0.0%
# Fees: 0
# Total Trades: 0
# Open Trades
# Open Orders:
# No open orders
# /home/joseph/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# ************** Live Trade Orders *****************
# No live trade orders
# *************** Open Trades ******************
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SNA
# UNP
# XYL
# Max ALlowable DD: -0.025958333333333312
# Max Allowable DD in run_backtest_2: None
# ____________________________ Summary _________________________________
# Symbols: ['SNA', 'UNP', 'XYL']
# Vectors: [86.29497056 17.27650116  4.59039552]
#
# Item                            value  Item                    Value
# ------------------------  -----------  -----------------  ----------
# Annualized Return            0.728265  Cumulative Return    0.265333
# Net Profit                1183.49
# Gross Profit              1230.14      Gross Loss         -46.65
# Reward Risk Ratio           79.7995    Equity Smoothness   32.7723
# Return Over Max Drawdown     8.54509
#
# ____________________________ Hypothesis Test _________________________________
#
# Item                         value  Item                           Value
# ---------------------  -----------  ---------------------------  -------
# Daily Sharpe Ratio       0.178663   Sharpe Ratio                 2.83619
# Number of Days         157          Sharpe Ratio Critical Value  2.23864
# Sharpe Ratio P Value:    0.0125896
# ****** Summary *******
# Annualized Return: 72.83%
# Max Drawdown: 3.1%
# Total Trading Days: 0
# Start Equity: 3000
# End Equity: 3796
# Profits: 796
# Cumulative Return: 26.53%
# Fees: 10.5
# Total Trades: 45
# Open Trades
# Open Orders:
# No open orders
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SNA
# UNP
# XYL
# Max ALlowable DD: -0.025958333333333312
# Max Allowable DD in run_backtest_2: -0.025958333333333312
# ____________________________ Summary _________________________________
# Symbols: ['SNA', 'UNP', 'XYL']
# Vectors: [86.29497056 17.27650116  4.59039552]
#
# Item                          value  Item                     Value
# ------------------------  ---------  -----------------  -----------
# Annualized Return          0         Cumulative Return  0
# Net Profit                 0
# Gross Profit               0         Gross Loss         0
# Reward Risk Ratio         -0.235702  Equity Smoothness  1.36424e-12
# Return Over Max Drawdown   0
#
# ____________________________ Hypothesis Test _________________________________
#
# Item                     value  Item                           Value
# ---------------------  -------  ---------------------------  -------
# Daily Sharpe Ratio         0    Sharpe Ratio                       0
# Number of Days             3    Sharpe Ratio Critical Value        0
# Sharpe Ratio P Value:      0.5
# ****** Summary *******
# Annualized Return: 0.0%
# Max Drawdown: -0.0%
# Total Trading Days: 0
# Start Equity: 3000
# End Equity: 3000
# Profits: 0
# Cumulative Return: 0.0%
# Fees: 0
# Total Trades: 0
# Open Trades
# Open Orders:
# No open orders
# /home/joseph/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# ************** Live Trade Orders *****************
# No live trade orders
# *************** Open Trades ******************
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ALK
# PCAR
# SNA
# Max ALlowable DD: -0.028822399121603122
# Max Allowable DD in run_backtest_2: None
# ____________________________ Summary _________________________________
# Symbols: ['ALK', 'PCAR', 'SNA']
# Vectors: [  1.30189017  -5.47692399 -17.0103304 ]
#
# Item                           value  Item                    Value
# ------------------------  ----------  -----------------  ----------
# Annualized Return            1.40787  Cumulative Return    0.459333
# Net Profit                1795.59
# Gross Profit              1840.87     Gross Loss         -45.28
# Reward Risk Ratio           77.7169   Equity Smoothness   58.211
# Return Over Max Drawdown    13.3582
#
# ____________________________ Hypothesis Test _________________________________
#
# Item                          value  Item                           Value
# ---------------------  ------------  ---------------------------  -------
# Daily Sharpe Ratio       0.239289    Sharpe Ratio                 3.79859
# Number of Days         157           Sharpe Ratio Critical Value  2.99828
# Sharpe Ratio P Value:    0.00135754
# ****** Summary *******
# Annualized Return: 140.79%
# Max Drawdown: 3.4%
# Total Trading Days: 0
# Start Equity: 3000
# End Equity: 4378
# Profits: 1378
# Cumulative Return: 45.93%
# Fees: 11.2
# Total Trades: 48
# Open Trades
# Open Orders:
# No open orders
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ALK
# PCAR
# SNA
# Max ALlowable DD: -0.028822399121603122
# Max Allowable DD in run_backtest_2: -0.028822399121603122
# ____________________________ Summary _________________________________
# Symbols: ['ALK', 'PCAR', 'SNA']
# Vectors: [  1.30189017  -5.47692399 -17.0103304 ]
#
# Item                          value  Item                     Value
# ------------------------  ---------  -----------------  -----------
# Annualized Return          0         Cumulative Return  0
# Net Profit                 0
# Gross Profit               0         Gross Loss         0
# Reward Risk Ratio         -0.235702  Equity Smoothness  1.36424e-12
# Return Over Max Drawdown   0
#
# ____________________________ Hypothesis Test _________________________________
#
# Item                     value  Item                           Value
# ---------------------  -------  ---------------------------  -------
# Daily Sharpe Ratio         0    Sharpe Ratio                       0
# Number of Days             3    Sharpe Ratio Critical Value        0
# Sharpe Ratio P Value:      0.5
# ****** Summary *******
# Annualized Return: 0.0%
# Max Drawdown: -0.0%
# Total Trading Days: 0
# Start Equity: 3000
# End Equity: 3000
# Profits: 0
# Cumulative Return: 0.0%
# Fees: 0
# Total Trades: 0
# Open Trades
# Open Orders:
# No open orders
# /home/joseph/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# ************** Live Trade Orders *****************
# No live trade orders
# *************** Open Trades ******************
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# RSG
# SNA
# URI
# Max ALlowable DD: -0.03523067705212701
# Max Allowable DD in run_backtest_2: None
# ____________________________ Summary _________________________________
# Symbols: ['RSG', 'SNA', 'URI']
# Vectors: [  4.46067875 -32.10084124 -10.63656438]
#
# Item                           value  Item                  Value
# ------------------------  ----------  -----------------  --------
# Annualized Return            1.08253  Cumulative Return    0.371
# Net Profit                1355.22
# Gross Profit              1454.94     Gross Loss         -99.7201
# Reward Risk Ratio           76.178    Equity Smoothness   50.5034
# Return Over Max Drawdown     8.19352
#
# ____________________________ Hypothesis Test _________________________________
#
# Item                         value  Item                           Value
# ---------------------  -----------  ---------------------------  -------
# Daily Sharpe Ratio       0.185178   Sharpe Ratio                 2.93961
# Number of Days         157          Sharpe Ratio Critical Value  2.32027
# Sharpe Ratio P Value:    0.0101631
# ****** Summary *******
# Annualized Return: 108.25%
# Max Drawdown: 4.5%
# Total Trading Days: 0
# Start Equity: 3000
# End Equity: 4113
# Profits: 1113
# Cumulative Return: 37.1%
# Fees: 11.2
# Total Trades: 36
# Open Trades
# -1.0 shares of RSG purchased on 2022-05-12 00:00:00 at 129.39
# 10.0 shares of SNA purchased on 2022-05-12 00:00:00 at 209.84
# 4.0 shares of URI purchased on 2022-05-12 00:00:00 at 276.86
# Open Orders:
# No open orders
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# RSG
# SNA
# URI
# Max ALlowable DD: -0.03523067705212701
# Max Allowable DD in run_backtest_2: -0.03523067705212701
# ____________________________ Summary _________________________________
# Symbols: ['RSG', 'SNA', 'URI']
# Vectors: [  4.46067875 -32.10084124 -10.63656438]
#
# Item                          value  Item                     Value
# ------------------------  ---------  -----------------  -----------
# Annualized Return          0         Cumulative Return  0
# Net Profit                 0
# Gross Profit               0         Gross Loss         0
# Reward Risk Ratio         -0.235702  Equity Smoothness  1.36424e-12
# Return Over Max Drawdown   0
#
# ____________________________ Hypothesis Test _________________________________
#
# Item                     value  Item                           Value
# ---------------------  -------  ---------------------------  -------
# Daily Sharpe Ratio         0    Sharpe Ratio                       0
# Number of Days             3    Sharpe Ratio Critical Value        0
# Sharpe Ratio P Value:      0.5
# ****** Summary *******
# Annualized Return: 0.0%
# Max Drawdown: -0.0%
# Total Trading Days: 0
# Start Equity: 3000
# End Equity: 3000
# Profits: 0
# Cumulative Return: 0.0%
# Fees: 0
# Total Trades: 0
# Open Trades
# Open Orders:
# No open orders
# /home/joseph/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# ************** Live Trade Orders *****************
# No live trade orders
# *************** Open Trades ******************
#
#
#
#
# ************************************** Live Closed Trades ****************************************************
# Empty DataFrame
# Columns: []
# Index: []
# ************************************** Live Open Trades ****************************************************
# Empty DataFrame
# Columns: []
# Index: []

# %%
lt.backtests[1].max_allowable_drawdown
# Out:
# 0.0

# %%
lt.price_df
# Out:
#              ALK_open  ALK_close  PCAR_open  PCAR_close    SNA_open  \
# Date
# 2022-05-12  45.240002  44.610001  82.430000   83.489998  209.839996
# 2022-05-13  45.279999  46.150002  83.800003   83.750000  215.949997
# 2022-05-16  45.930000  45.599998  84.040001   83.279999  215.929993
#
#              SNA_close    GWW_open   GWW_close   WAB_open  WAB_close  ...  \
# Date                                                                  ...
# 2022-05-12  214.750000  457.420013  469.239990  84.480003  85.959999  ...
# 2022-05-13  216.490005  473.049988  477.329987  86.779999  86.790001  ...
# 2022-05-16  216.839996         NaN         NaN        NaN        NaN  ...
#
#              ODFL_open  ODFL_close     TT_open    TT_close    RSG_open  \
# Date
# 2022-05-12  268.359985  269.649994  130.389999  134.429993  129.389999
# 2022-05-13  271.619995  273.119995  135.369995  137.979996  129.500000
# 2022-05-16  271.399994  262.480011  137.000000  135.410004  130.889999
#
#              RSG_close    URI_open   URI_close   XYL_open  XYL_close
# Date
# 2022-05-12  127.720001  276.859985  283.019989  80.160004  82.790001
# 2022-05-13  130.889999  285.549988  288.440002  83.669998  83.910004
# 2022-05-16  130.820007  286.140015  282.929993  82.349998  81.800003
#
# [3 rows x 26 columns]
